# %%
import pandas as pd 


silo_raw = pd.read_csv(r"data\Site_Status_02-06-2025_355928.csv")
# Remove single quotes from all string values in the DataFrame
silo_raw = silo_raw.map(lambda x: x.strip("'") if isinstance(x, str) else x)
silo_raw.head()
# Out:
#       Measurement Time              Site Vessel Name Contents Vessel Type  \
# 0  2/6/2025 7:00:31 AM  Current Location     Silo 01    LL218    CYLINDER
# 1  2/6/2025 7:01:20 AM  Current Location     Silo 02    LL625    CYLINDER
# 2  2/6/2025 7:00:41 AM  Current Location     Silo 03    LL318    CYLINDER
# 3  2/6/2025 7:01:25 AM  Current Location     Silo 04       LL    CYLINDER
# 4  2/6/2025 7:00:21 AM  Current Location     Silo 05    LL511    CYLINDER
#
#   Distance Units Volume Units Weight Units  Vessel Height  Vessel Radius  ...  \
# 0             ft        cu ft          lbs           74.0            7.0  ...
# 1             ft        cu ft          lbs           74.0            7.0  ...
# 2             ft        cu ft          lbs           56.0            6.0  ...
# 3             ft        cu ft          lbs           74.0            7.0  ...
# 4             ft        cu ft          lbs           74.0            7.0  ...
#
# ...
